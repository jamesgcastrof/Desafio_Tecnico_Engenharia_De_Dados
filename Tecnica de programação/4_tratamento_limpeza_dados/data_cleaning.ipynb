# %% [markdown]
# # Tratamento, Limpeza e Análise de Dados: Revelando Insights

# %% [markdown]
# Dataset utilizado: Airbnb Open Data
# https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata?resource=download

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Importando e visualizando o dataset

# %%
pd.set_option('display.max_columns', None)

columns = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review', 'reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules']

df = pd.read_csv("Airbnb_Open_Data.csv", usecols = columns)

# %%
df.head(5)
# Out:
#                                                NAME      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# 1  40.75362 -73.98377  United States           US            False
# 2  40.80902 -73.94190  United States           US             True
# 3  40.68514 -73.95976  United States           US             True
# 4  40.79851 -73.94399  United States           US            False
#
#   cancellation_policy        room type  Construction year  price service fee  \
# 0              strict     Private room             2020.0  $966        $193
# 1            moderate  Entire home/apt             2007.0  $142         $28
# 2            flexible     Private room             2005.0  $620        $124
# 3            moderate  Entire home/apt             2005.0  $368         $74
# 4            moderate  Entire home/apt             2009.0  $204         $41
#
#    minimum nights  number of reviews last review  reviews per month  \
# 0            10.0                9.0  10/19/2021               0.21
# 1            30.0               45.0   5/21/2022               0.38
# 2             3.0                0.0         NaN                NaN
# 3            30.0              270.0    7/5/2019               4.64
# 4            10.0                9.0  11/19/2018               0.10
#
#    review rate number  calculated host listings count  availability 365  \
# 0                 4.0                             6.0             286.0
# 1                 4.0                             2.0             228.0
# 2                 5.0                             1.0             352.0
# 3                 4.0                             1.0             322.0
# 4                 3.0                             1.0             289.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
# 3                                                NaN
# 4  Please no smoking in the house, porch or on th...

# %%
df.dtypes
# Out:
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# house_rules                        object
# dtype: object

# %%
len(df)
# Out:
# 102599

# %%
df.describe()
# Out:
#             host id            lat           long  Construction year  \
# count  1.025990e+05  102591.000000  102591.000000      102385.000000
# mean   4.925411e+10      40.728094     -73.949644        2012.487464
# std    2.853900e+10       0.055857       0.049521           5.765556
# min    1.236005e+08      40.499790     -74.249840        2003.000000
# 25%    2.458333e+10      40.688740     -73.982580        2007.000000
# 50%    4.911774e+10      40.722290     -73.954440        2012.000000
# 75%    7.399650e+10      40.762760     -73.932350        2017.000000
# max    9.876313e+10      40.916970     -73.705220        2022.000000
#
#        minimum nights  number of reviews  reviews per month  \
# count   102190.000000      102416.000000       86720.000000
# mean         8.135845          27.483743           1.374022
# std         30.553781          49.508954           1.746621
# min      -1223.000000           0.000000           0.010000
# 25%          2.000000           1.000000           0.220000
# 50%          3.000000           7.000000           0.740000
# 75%          5.000000          30.000000           2.000000
# max       5645.000000        1024.000000          90.000000
#
#        review rate number  calculated host listings count  availability 365
# count       102273.000000                   102280.000000     102151.000000
# mean             3.279106                        7.936605        141.133254
# std              1.284657                       32.218780        135.435024
# min              1.000000                        1.000000        -10.000000
# 25%              2.000000                        1.000000          3.000000
# 50%              3.000000                        1.000000         96.000000
# 75%              4.000000                        2.000000        269.000000
# max              5.000000                      332.000000       3677.000000

# %% [markdown]
# #### Cálculo de "missing values" (valores nulos) - NaN

# %%
per_df = df.isnull().sum()/df.shape[0] * 100
per_df = pd.DataFrame({"colunas": per_df.keys(), "missing values %": per_df.round(2), "data type": df.dtypes})
per_df.reset_index(drop=True, inplace=True)
per_df = per_df.sort_values(by='missing values %',ascending=False)
per_df
# Out:
#                            colunas  missing values % data type
# 23                     house_rules             50.81    object
# 18                     last review             15.49    object
# 19               reviews per month             15.48   float64
# 8                          country              0.52    object
# 22                availability 365              0.44   float64
# 3                        host name              0.40    object
# 16                  minimum nights              0.40   float64
# 20              review rate number              0.32   float64
# 21  calculated host listings count              0.31   float64
# 2           host_identity_verified              0.28    object
# 15                     service fee              0.27    object
# 14                           price              0.24    object
# 0                             NAME              0.24    object
# 13               Construction year              0.21   float64
# 17               number of reviews              0.18   float64
# 9                     country code              0.13    object
# 10                instant_bookable              0.10    object
# 11             cancellation_policy              0.07    object
# 4              neighbourhood group              0.03    object
# 5                    neighbourhood              0.02    object
# 7                             long              0.01   float64
# 6                              lat              0.01   float64
# 1                          host id              0.00     int64
# 12                       room type              0.00    object

# %% [markdown]
# ## Tratamento e limpeza dos dados

# %% [markdown]
# #### Trata preços

# %%
def trata_preços(value):
    if pd.isna(value):
        return np.NaN
    else:
        return float(value.replace("$", "").replace(",", "").replace(" ", ""))

# %%
df["price"] = df["price"].apply(lambda x: trata_preços(x))
df["service fee"] = df["service fee"].apply(lambda x: trata_preços(x))

# %% [markdown]
# #### Trata nulos

# %%
def trata_NaN_values(df, column_name):
    # Substituir NaN por 0 e converter para inteiro
    df[column_name] = np.array(df[column_name].fillna(0), dtype=np.int16)
    return df

# %%
df = trata_NaN_values(df,'reviews per month')
df = trata_NaN_values(df,'availability 365')
df = trata_NaN_values(df,'minimum nights')
df = trata_NaN_values(df,'number of reviews')
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 2                         NaN        Elise           Manhattan
# 3                 unconfirmed        Garry            Brooklyn
# 4                    verified       Lyndon           Manhattan
# ...                       ...          ...                 ...
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594            False            flexible     Private room
# 102595             True            moderate     Private room
# 102596             True            moderate     Private room
# 102597             True              strict  Entire home/apt
# 102598            False            flexible  Entire home/apt
#
#         Construction year   price  service fee  minimum nights  \
# 0                  2020.0   966.0        193.0              10
# 1                  2007.0   142.0         28.0              30
# 2                  2005.0   620.0        124.0               3
# 3                  2005.0   368.0         74.0              30
# 4                  2009.0   204.0         41.0              10
# ...                   ...     ...          ...             ...
# 102594             2003.0   844.0        169.0               1
# 102595             2016.0   837.0        167.0               1
# 102596             2009.0   988.0        198.0               3
# 102597             2015.0   546.0        109.0               2
# 102598             2010.0  1032.0        206.0               1
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                       9  10/19/2021                  0                 4.0
# 1                      45   5/21/2022                  0                 4.0
# 2                       0         NaN                  0                 5.0
# 3                     270    7/5/2019                  4                 4.0
# 4                       9  11/19/2018                  0                 3.0
# ...                   ...         ...                ...                 ...
# 102594                  0         NaN                  0                 3.0
# 102595                  1    7/6/2015                  0                 2.0
# 102596                  0         NaN                  0                 5.0
# 102597                  5  10/11/2015                  0                 3.0
# 102598                  0         NaN                  0                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0               286
# 1                                  2.0               228
# 2                                  1.0               352
# 3                                  1.0               322
# 4                                  1.0               289
# ...                                ...               ...
# 102594                             1.0               227
# 102595                             2.0               395
# 102596                             1.0               342
# 102597                             1.0               386
# 102598                             1.0                69
#
#                                               house_rules
# 0       Clean up and treat the home the way you'd like...
# 1       Pet friendly but please confirm with me if the...
# 2       I encourage you to use my kitchen, cooking and...
# 3                                                     NaN
# 4       Please no smoking in the house, porch or on th...
# ...                                                   ...
# 102594  No Smoking No Parties or Events of any kind Pl...
# 102595  House rules: Guests agree to the following ter...
# 102596                                                NaN
# 102597                                                NaN
# 102598                                                NaN
#
# [102599 rows x 24 columns]

# %% [markdown]
# #### Trata datas

# %%
def trata_datas(df, column_name, new_column_name):
    df[column_name] = pd.to_datetime(df[column_name], errors='coerce')
    
    def formato_safra(data):
        if pd.notnull(data):
            return data.strftime('%y%m')
        else:
            return None
    df[new_column_name] = df[column_name].apply(formato_safra)
    
    return df

# %%
df = trata_datas(df, 'last review', 'last review safra')
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 2                         NaN        Elise           Manhattan
# 3                 unconfirmed        Garry            Brooklyn
# 4                    verified       Lyndon           Manhattan
# ...                       ...          ...                 ...
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594            False            flexible     Private room
# 102595             True            moderate     Private room
# 102596             True            moderate     Private room
# 102597             True              strict  Entire home/apt
# 102598            False            flexible  Entire home/apt
#
#         Construction year   price  service fee  minimum nights  \
# 0                  2020.0   966.0        193.0              10
# 1                  2007.0   142.0         28.0              30
# 2                  2005.0   620.0        124.0               3
# 3                  2005.0   368.0         74.0              30
# 4                  2009.0   204.0         41.0              10
# ...                   ...     ...          ...             ...
# 102594             2003.0   844.0        169.0               1
# 102595             2016.0   837.0        167.0               1
# 102596             2009.0   988.0        198.0               3
# 102597             2015.0   546.0        109.0               2
# 102598             2010.0  1032.0        206.0               1
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                       9  2021-10-19                  0                 4.0
# 1                      45  2022-05-21                  0                 4.0
# 2                       0         NaT                  0                 5.0
# 3                     270  2019-07-05                  4                 4.0
# 4                       9  2018-11-19                  0                 3.0
# ...                   ...         ...                ...                 ...
# 102594                  0         NaT                  0                 3.0
# 102595                  1  2015-07-06                  0                 2.0
# 102596                  0         NaT                  0                 5.0
# 102597                  5  2015-10-11                  0                 3.0
# 102598                  0         NaT                  0                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0               286
# 1                                  2.0               228
# 2                                  1.0               352
# 3                                  1.0               322
# 4                                  1.0               289
# ...                                ...               ...
# 102594                             1.0               227
# 102595                             2.0               395
# 102596                             1.0               342
# 102597                             1.0               386
# 102598                             1.0                69
#
#                                               house_rules last review safra
# 0       Clean up and treat the home the way you'd like...              2110
# 1       Pet friendly but please confirm with me if the...              2205
# 2       I encourage you to use my kitchen, cooking and...              None
# 3                                                     NaN              1907
# 4       Please no smoking in the house, porch or on th...              1811
# ...                                                   ...               ...
# 102594  No Smoking No Parties or Events of any kind Pl...              None
# 102595  House rules: Guests agree to the following ter...              1507
# 102596                                                NaN              None
# 102597                                                NaN              1510
# 102598                                                NaN              None
#
# [102599 rows x 25 columns]

# %% [markdown]
# ## Extração dos dados

# %% [markdown]
# #### Extração de .csv por safra

# %%
def divide_e_salva_por_safra(df, coluna_safra,valor_safra):
    df_temp = df[df[coluna_safra] == valor_safra]
    nome_arquivo = f'{coluna_safra}_{valor_safra}.csv'
    df_temp.to_csv(nome_arquivo, index=False)
    print(f'Dados salvos em {nome_arquivo}')
    return df_temp

# %%
df_oct_21 = divide_e_salva_por_safra(df, 'last review safra', '2110')
df_oct_21
# Out:
# Dados salvos em last review safra_2110.csv
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 62783                 Creative Director's Chinatown Loft  74591413544
# 62784                    Convenient East Village Studio,  56004838653
# 62785  Central Harlem Clean Furnished Room (Near Apollo)  59435762062
# 62786                 Furnished 1 Bedroom in East Harlem  51552178229
# ...                                                  ...          ...
# 63547                Entire Apartment: Clean & Cozy 1 BR  89633259530
# 63548        Bedroom in luxury upper west side apartment  83396261986
# 63549  Brand new private rooms looking for new habita...  67790331986
# 63550  1- bedroom in a 3 bedroom apartment  1 share bath  32413916079
# 63551   “Rustic Urban Cocktail Retreat”: Bright Air Cozy  49444604864
#
#       host_identity_verified host name neighbourhood group  \
# 0                unconfirmed  Madaline            Brooklyn
# 62783               verified      Todd           Manhattan
# 62784               verified     Leigh           Manhattan
# 62785               verified   Anthony           Manhattan
# 62786            unconfirmed  Jeremiah           Manhattan
# ...                      ...       ...                 ...
# 63547            unconfirmed      Kwam            Brooklyn
# 63548               verified    Maegan           Manhattan
# 63549            unconfirmed       NaN           Manhattan
# 63550            unconfirmed    Daniel            Brooklyn
# 63551            unconfirmed      Paul            Brooklyn
#
#             neighbourhood       lat      long        country country code  \
# 0              Kensington  40.64749 -73.97237  United States           US
# 62783           Chinatown  40.71502 -73.99170  United States           US
# 62784        East Village  40.72989 -73.97988  United States           US
# 62785              Harlem  40.81213 -73.95380  United States           US
# 62786         East Harlem  40.79292 -73.93953  United States           US
# ...                   ...       ...       ...            ...          ...
# 63547            Bushwick  40.70550 -73.91841  United States           US
# 63548     Upper West Side  40.80203 -73.96501  United States           US
# 63549              Harlem  40.81983 -73.93989  United States           US
# 63550            Bushwick  40.69029 -73.91532  United States           US
# 63551  Bedford-Stuyvesant  40.68322 -73.95626  United States           US
#
#       instant_bookable cancellation_policy        room type  \
# 0                False              strict     Private room
# 62783             True            flexible  Entire home/apt
# 62784             True            moderate  Entire home/apt
# 62785            False            moderate     Private room
# 62786             True            moderate  Entire home/apt
# ...                ...                 ...              ...
# 63547             True            flexible  Entire home/apt
# 63548            False            flexible     Private room
# 63549            False            flexible     Private room
# 63550             True              strict      Shared room
# 63551            False            flexible  Entire home/apt
#
#        Construction year   price  service fee  minimum nights  \
# 0                 2020.0   966.0        193.0              10
# 62783             2008.0   379.0         76.0              14
# 62784             2009.0   960.0        192.0              30
# 62785             2013.0  1117.0        223.0              30
# 62786             2015.0   679.0        136.0              30
# ...                  ...     ...          ...             ...
# 63547             2008.0   480.0         96.0              30
# 63548             2018.0    67.0         13.0              25
# 63549             2021.0   127.0         25.0              30
# 63550             2013.0   675.0        135.0               3
# 63551             2003.0   491.0         98.0               3
#
#        number of reviews last review  reviews per month  review rate number  \
# 0                      9  2021-10-19                  0                 4.0
# 62783                 19  2021-10-31                  0                 5.0
# 62784                167  2021-10-31                  1                 2.0
# 62785                 26  2021-10-31                  0                 3.0
# 62786                 41  2021-10-31                  0                 3.0
# ...                  ...         ...                ...                 ...
# 63547                  1  2021-10-01                  0                 4.0
# 63548                  1  2021-10-01                  0                 5.0
# 63549                  1  2021-10-01                  0                 2.0
# 63550                  1  2021-10-01                  0                 4.0
# 63551                  1  2021-10-01                  0                 5.0
#
#        calculated host listings count  availability 365  \
# 0                                 6.0               286
# 62783                             1.0               213
# 62784                             1.0                45
# 62785                             1.0               101
# 62786                             1.0                 8
# ...                               ...               ...
# 63547                             1.0               277
# 63548                             3.0                 0
# 63549                            45.0                58
# 63550                             2.0               365
# 63551                             4.0               364
#
#                                              house_rules last review safra
# 0      Clean up and treat the home the way you'd like...              2110
# 62783                                                NaN              2110
# 62784                                                NaN              2110
# 62785                                                NaN              2110
# 62786                                                NaN              2110
# ...                                                  ...               ...
# 63547                                                NaN              2110
# 63548                                                NaN              2110
# 63549                                                NaN              2110
# 63550                                                NaN              2110
# 63551                                                NaN              2110
#
# [770 rows x 25 columns]

# %%
df_oct_20 = divide_e_salva_por_safra(df, 'last review safra', '2010')
df_oct_20
# Out:
# Dados salvos em last review safra_2010.csv
#                                                    NAME      host id  \
# 66547      Monthly discount - 2 bedroom upper east side  38335783575
# 66548                    Private Suite, Free Metrocard*  77855762275
# 66549  Studio w/CV: Cleaning CDC guidelines implemented  92881530321
# 66550                   Spacious and sunny private room  51706249711
# 66551                Cozy apt convenient to everything!  18114417251
# ...                                                 ...          ...
# 66723            Modern Twin Room | Free GYM, coworking  10611509245
# 66724             Peace & Solace in Prospect Park South  23241702433
# 66725      Popular Room NEW Apartment Williamsburg 2020  57636639965
# 66726                2 Bedrooms - Great Location in NYC  86793381748
# 66727       Fully Furnished, 2 Bedroom apartment in PLG  27642481122
#
#       host_identity_verified            host name neighbourhood group  \
# 66547               verified                    D           Manhattan
# 66548            unconfirmed            Christina              Queens
# 66549            unconfirmed                 Vida            Brooklyn
# 66550            unconfirmed                Diego              Queens
# 66551            unconfirmed                 Ruby           Manhattan
# ...                      ...                  ...                 ...
# 66723               verified  SharedEasy Coliving            Brooklyn
# 66724            unconfirmed                Lucky            Brooklyn
# 66725            unconfirmed                Shogo            Brooklyn
# 66726            unconfirmed               Louise              Queens
# 66727               verified               Nebiat            Brooklyn
#
#                    neighbourhood       lat      long        country  \
# 66547            Upper East Side  40.77031 -73.95098  United States
# 66548                   Flushing  40.75046 -73.80969  United States
# 66549                 Greenpoint  40.72690 -73.94198  United States
# 66550                  Ridgewood  40.70835 -73.91158  United States
# 66551               East Village  40.72556 -73.99036  United States
# ...                          ...       ...       ...            ...
# 66723         Bedford-Stuyvesant  40.68175 -73.94466  United States
# 66724                   Flatbush  40.65126 -73.96095  United States
# 66725               Williamsburg  40.70330 -73.94197  United States
# 66726                    Astoria  40.76548 -73.91833  United States
# 66727  Prospect-Lefferts Gardens  40.66009 -73.95408  United States
#
#       country code instant_bookable cancellation_policy        room type  \
# 66547           US            False              strict  Entire home/apt
# 66548           US            False            moderate     Private room
# 66549           US             True              strict  Entire home/apt
# 66550           US             True              strict     Private room
# 66551           US             True              strict  Entire home/apt
# ...            ...              ...                 ...              ...
# 66723           US             True            moderate      Shared room
# 66724           US             True              strict     Private room
# 66725           US            False            moderate     Private room
# 66726           US             True            moderate  Entire home/apt
# 66727           US             True              strict  Entire home/apt
#
#        Construction year  price  service fee  minimum nights  \
# 66547             2014.0  605.0        121.0              30
# 66548             2014.0  805.0        161.0               2
# 66549             2015.0  265.0         53.0              30
# 66550             2013.0  531.0        106.0              30
# 66551             2008.0  261.0         52.0              30
# ...                  ...    ...          ...             ...
# 66723             2011.0  517.0        103.0              30
# 66724             2014.0   84.0         17.0              30
# 66725             2019.0  462.0         92.0              30
# 66726             2007.0  815.0        163.0              30
# 66727             2013.0  148.0         30.0               1
#
#        number of reviews last review  reviews per month  review rate number  \
# 66547                  2  2020-10-31                  0                 2.0
# 66548                352  2020-10-31                  3                 2.0
# 66549                  8  2020-10-31                  0                 5.0
# 66550                 56  2020-10-31                  0                 3.0
# 66551                 11  2020-10-31                  0                 5.0
# ...                  ...         ...                ...                 ...
# 66723                  1  2020-10-01                  0                 4.0
# 66724                  2  2020-10-01                  0                 2.0
# 66725                  1  2020-10-01                  0                 5.0
# 66726                  2  2020-10-01                  0                 2.0
# 66727                  2  2020-10-01                  0                 3.0
#
#        calculated host listings count  availability 365 house_rules  \
# 66547                             3.0               185         NaN
# 66548                             2.0               137         NaN
# 66549                            28.0               277         NaN
# 66550                             3.0               264         NaN
# 66551                             1.0               173         NaN
# ...                               ...               ...         ...
# 66723                             8.0               288         NaN
# 66724                             2.0                88         NaN
# 66725                           125.0                60         NaN
# 66726                             2.0                 0         NaN
# 66727                             1.0                 0         NaN
#
#       last review safra
# 66547              2010
# 66548              2010
# 66549              2010
# 66550              2010
# 66551              2010
# ...                 ...
# 66723              2010
# 66724              2010
# 66725              2010
# 66726              2010
# 66727              2010
#
# [181 rows x 25 columns]

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# #### Comparação de preço  médio por safras

# %%
safra = ['10-2021', '10-2020']
preco_medio = [df_oct_21['price'].mean().round(1), df_oct_20['price'].mean().round(1)]

# %% [markdown]
# ##### Comparação em tabelas

# %%
df_precos_medios = pd.DataFrame({
    'Safra': safra,
    'Preço Médio': preco_medio
})
df_precos_medios
# Out:
#      Safra  Preço Médio
# 0  10-2021        606.5
# 1  10-2020        588.3

# %% [markdown]
# ##### Comparação em gráficos

# %%
plt.figure(figsize=(8, 6))
plt.bar(safra, preco_medio, color=['blue', 'orange'])
plt.title('Preço Médio em Outubro de 2020 e Outubro de 2021')
plt.xlabel('Datas')
plt.ylabel('Preço Médio')
plt.ylim(0, 1000) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### Comparação de média de avaliações por safras

# %%
safra = ['10-2021', '10-2020']
media_avaliacoes = [df_oct_21['review rate number'].mean().round(1), df_oct_20['review rate number'].mean().round(1)]

# %% [markdown]
# ##### Comparação em tabelas

# %%
df_media_reviews = pd.DataFrame({
    'Safra': safra,
    'Média Avaliações': media_avaliacoes
})
df_media_reviews
# Out:
#      Safra  Média Avaliações
# 0  10-2021               3.5
# 1  10-2020               3.5

# %% [markdown]
# ##### Comparação em gráficos

# %%
plt.figure(figsize=(8, 6))
plt.bar(safra, media_avaliacoes, color=['blue', 'orange'])
plt.title('Média de Avaliações em Outubro de 2020 e Outubro de 2021')
plt.xlabel('Datas')
plt.ylabel('Média de Avaliações')
plt.ylim(0, 5) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
